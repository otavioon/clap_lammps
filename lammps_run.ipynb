# %% [markdown]
# # Chapter 4 Experiments

# %%
import sys
import os
import yaml
from dataclasses import asdict
from pathlib import Path

sys.path.append("./CLAP")
current_dir = os.getcwd()

# %%
from app.cli.modules.node import get_config_db, get_node_manager
from app.cli.modules.role import get_role_manager
from app.cli.modules.cluster import get_cluster_config_db, get_cluster_manager
from clap.utils import float_time_to_string

# %%
instance_config_db = get_config_db()
cluster_config_db = get_cluster_config_db()
node_manager = get_node_manager()
role_manager = get_role_manager()
cluster_manager = get_cluster_manager()
private_path = node_manager.private_path

# %%
cluster_conf = cluster_config_db.clusters["lammps-cluster"]
cluster_manager.start_cluster(cluster_conf)
# Out:
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-type-t2.medium instances (timeout 600 seconds)] ********
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-046310ea085e2ae4d', 'name': 'WilliamLouder-59794c67'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-type-t2.large instances (timeout 600 seconds)] *********
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-09fedbcae0018124c', 'name': 'BarbaraMorgan-af385a34'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-c5.large instances (timeout 600 seconds)] **************
# [DEPRECATION WARNING]: The 'ec2' module has been deprecated and replaced by the
#  'ec2_instance' module'. This feature will be removed from amazon.aws in
# version 4.0.0. Deprecation warnings can be disabled by setting
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-020a77dc9a5739185', 'name': 'SusanSchwalb-4845d979'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-m5.2xlarge instances (timeout 600 seconds)] ************
# [DEPRECATION WARNING]: The 'ec2' module has been deprecated and replaced by the
#  'ec2_instance' module'. This feature will be removed from amazon.aws in
# version 4.0.0. Deprecation warnings can be disabled by setting
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-0ec26d18f42961d4a', 'name': 'GladysLee-bd768c6a'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r5.xlarge instances (timeout 600 seconds)] *************
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-0c63b6b2b37d8e405', 'name': 'ShaneMadore-fcd71ec3'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-m5a.2xlarge instances (timeout 600 seconds)] ***********
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-0d1fb153ae97e2e08', 'name': 'KennethLeslie-419951bb'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r5a.xlarge instances (timeout 600 seconds)] ************
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-09c073d37862da62a', 'name': 'SharonWarner-7b302524'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r4.xlarge instances (timeout 600 seconds)] *************
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-033a80774c86771d3', 'name': 'GeorginaLy-055a1b8e'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r4.2xlarge instances (timeout 600 seconds)] ************
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-03e3192abd9ee7288', 'name': 'SarahDemello-1c674064'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-m4.2xlarge instances (timeout 600 seconds)] ************
# [DEPRECATION WARNING]: The 'ec2' module has been deprecated and replaced by the
#  'ec2_instance' module'. This feature will be removed from amazon.aws in
# version 4.0.0. Deprecation warnings can be disabled by setting
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-0cd0fd55688fba5d7', 'name': 'BoydWalton-5b9555a2'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r5.2xlarge instances (timeout 600 seconds)] ************
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-01ff742ba2bf7ef31', 'name': 'MattieRousse-dc8897c9'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r5a.2xlarge instances (timeout 600 seconds)] ***********
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-0539f2ec979c8718e', 'name': 'MaryLewis-98eaa8f4'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-c5.4xlarge instances (timeout 600 seconds)] ************
# [DEPRECATION WARNING]: The 'ec2' module has been deprecated and replaced by the
#  'ec2_instance' module'. This feature will be removed from amazon.aws in
# version 4.0.0. Deprecation warnings can be disabled by setting
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-010c4a66da843750a', 'name': 'DerekBenningfield-9b52a6a9'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-r5.4xlarge instances (timeout 600 seconds)] ************
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-03d3318f316efb1f3', 'name': 'RyanOliver-b73ea280'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Starting 1 lammps-x1e.2xlarge instances (timeout 600 seconds)] ***********
# [DEPRECATION WARNING]: The 'ec2' module has been deprecated and replaced by the
#  'ec2_instance' module'. This feature will be removed from amazon.aws in
# version 4.0.0. Deprecation warnings can be disabled by setting
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [localhost] ***************************************************************
#
# TASK [Tagging instances] *******************************************************
# changed: [localhost] => (item={'id': 'i-0c44f9ec6d07a3c87', 'name': 'BrittanyLohmann-17505645'})
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 'cluster-6ac142b83b4b4b72920c8ec9bfee8a62'

# %%
cluster = cluster_manager.get_all_clusters()[0]
cluster
# Out:
# ClusterDescriptor(cluster_id='cluster-6ac142b83b4b4b72920c8ec9bfee8a62', cluster_name='ImmatureBintree', cluster_config=ClusterConfig(cluster_config_id='lammps-cluster', options=None, before_all=[], before=[], after_all=[], after=[SetupConfig(roles=[RoleAdd(name='lammps', extra={})], actions=[])], nodes={'cluster-lammps-type-t2.medium': NodeConfig(type='lammps-type-t2.medium', count=1, min_count=1, setups=[]), 'cluster-lammps-type-t2.large': NodeConfig(type='lammps-type-t2.large', count=1, min_count=1, setups=[]), 'cluster-lammps-c5.large': NodeConfig(type='lammps-c5.large', count=1, min_count=1, setups=[]), 'cluster-lammps-m5.2xlarge': NodeConfig(type='lammps-m5.2xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r5.xlarge': NodeConfig(type='lammps-r5.xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-m5a.2xlarge': NodeConfig(type='lammps-m5a.2xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r5a.xlarge': NodeConfig(type='lammps-r5a.xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r4.xlarge': NodeConfig(type='lammps-r4.xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r4.2xlarge': NodeConfig(type='lammps-r4.2xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-m4.2xlarge': NodeConfig(type='lammps-m4.2xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r5.2xlarge': NodeConfig(type='lammps-r5.2xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r5a.2xlarge': NodeConfig(type='lammps-r5a.2xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-c5.4xlarge': NodeConfig(type='lammps-c5.4xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-r5.4xlarge': NodeConfig(type='lammps-r5.4xlarge', count=1, min_count=1, setups=[]), 'cluster-lammps-x1e.2xlarge': NodeConfig(type='lammps-x1e.2xlarge', count=1, min_count=1, setups=[])}), creation_time=1655477454.0040953, update_time=1655477777.40039, is_setup=False)

# %%
cluster_manager.is_alive(cluster.cluster_id)
# Out:
# {'59794c67db354b7f87340624c04e4dd0': True,
#  'af385a34e484447bbad51afad3beb5c8': True,
#  '4845d9798a284a6c9186c949c3cbb3d4': True,
#  'bd768c6a66f445e7a11351a667e42b8a': True,
#  'fcd71ec358ca49bcb6e43257a90b5b68': True,
#  '419951bb461247c68b34115e596fb2da': True,
#  '7b30252402984d268d838fc9a8468fb7': True,
#  '055a1b8ed33e4070b12f8544aea86cd2': True,
#  '1c674064c6324a90a13bf6b092afd80a': True,
#  '5b9555a28ceb47e0b64aa6eafe108c9a': True,
#  'dc8897c9bd31486dab80009367ef3385': True,
#  '98eaa8f47b444cf3afc295102886c2ac': True,
#  '9b52a6a911cd401bb4c0e7985a12089a': True,
#  'b73ea280daca4f91a50b13844ba26b3c': True,
#  '17505645616247a79c8f70ffd08778c1': True}

# %%
cluster_manager.setup_cluster(cluster.cluster_id)

# %%
node_ids = cluster_manager.get_all_cluster_nodes(cluster.cluster_id)
node_ids
# Out:
# ['59794c67db354b7f87340624c04e4dd0',
#  'af385a34e484447bbad51afad3beb5c8',
#  '4845d9798a284a6c9186c949c3cbb3d4',
#  'bd768c6a66f445e7a11351a667e42b8a',
#  'fcd71ec358ca49bcb6e43257a90b5b68',
#  '419951bb461247c68b34115e596fb2da',
#  '7b30252402984d268d838fc9a8468fb7',
#  '055a1b8ed33e4070b12f8544aea86cd2',
#  '1c674064c6324a90a13bf6b092afd80a',
#  '5b9555a28ceb47e0b64aa6eafe108c9a',
#  'dc8897c9bd31486dab80009367ef3385',
#  '98eaa8f47b444cf3afc295102886c2ac',
#  '9b52a6a911cd401bb4c0e7985a12089a',
#  'b73ea280daca4f91a50b13844ba26b3c',
#  '17505645616247a79c8f70ffd08778c1']

# %%
# Just checking if nodes above belong to lammps role
role_manager.get_all_role_nodes("lammps")
# Out:
# ['59794c67db354b7f87340624c04e4dd0',
#  'af385a34e484447bbad51afad3beb5c8',
#  '4845d9798a284a6c9186c949c3cbb3d4',
#  'bd768c6a66f445e7a11351a667e42b8a',
#  'fcd71ec358ca49bcb6e43257a90b5b68',
#  '419951bb461247c68b34115e596fb2da',
#  '7b30252402984d268d838fc9a8468fb7',
#  '055a1b8ed33e4070b12f8544aea86cd2',
#  '1c674064c6324a90a13bf6b092afd80a',
#  '5b9555a28ceb47e0b64aa6eafe108c9a',
#  'dc8897c9bd31486dab80009367ef3385',
#  '98eaa8f47b444cf3afc295102886c2ac',
#  '9b52a6a911cd401bb4c0e7985a12089a',
#  'b73ea280daca4f91a50b13844ba26b3c',
#  '17505645616247a79c8f70ffd08778c1']

# %%
extra_args = {
    "bench": "in.rhodo"
}
res = role_manager.perform_action("lammps", "run-localhost", node_ids, extra_args=extra_args)
# Out:
# PLAY [Run LAMMPS application] **************************************************
#
# TASK [Run LAMMPS] **************************************************************
# ASYNC POLL on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444 started=1 finished=0
# ASYNC POLL on bd768c6a66f445e7a11351a667e42b8a: jid=566750697777.1554 started=1 finished=0
# ASYNC POLL on 59794c67db354b7f87340624c04e4dd0: jid=578073256651.1453 started=1 finished=0
# ASYNC POLL on af385a34e484447bbad51afad3beb5c8: jid=546766599326.1450 started=1 finished=0
# ASYNC POLL on fcd71ec358ca49bcb6e43257a90b5b68: jid=584743802737.1487 started=1 finished=0
# ASYNC POLL on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444 started=1 finished=0
# ASYNC POLL on bd768c6a66f445e7a11351a667e42b8a: jid=566750697777.1554 started=1 finished=0
# ASYNC POLL on 59794c67db354b7f87340624c04e4dd0: jid=578073256651.1453 started=1 finished=0
# ASYNC POLL on af385a34e484447bbad51afad3beb5c8: jid=546766599326.1450 started=1 finished=0
# ASYNC POLL on fcd71ec358ca49bcb6e43257a90b5b68: jid=584743802737.1487 started=1 finished=0
# ASYNC POLL on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444 started=1 finished=0
# ASYNC POLL on fcd71ec358ca49bcb6e43257a90b5b68: jid=584743802737.1487 started=1 finished=0
# ASYNC POLL on 59794c67db354b7f87340624c04e4dd0: jid=578073256651.1453 started=1 finished=0
# ASYNC POLL on af385a34e484447bbad51afad3beb5c8: jid=546766599326.1450 started=1 finished=0
# ASYNC OK on bd768c6a66f445e7a11351a667e42b8a: jid=566750697777.1554
# changed: [bd768c6a66f445e7a11351a667e42b8a]
# ASYNC POLL on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444 started=1 finished=0
# ASYNC POLL on 59794c67db354b7f87340624c04e4dd0: jid=578073256651.1453 started=1 finished=0
# ASYNC POLL on af385a34e484447bbad51afad3beb5c8: jid=546766599326.1450 started=1 finished=0
# ASYNC OK on fcd71ec358ca49bcb6e43257a90b5b68: jid=584743802737.1487
# changed: [fcd71ec358ca49bcb6e43257a90b5b68]
# ASYNC POLL on 419951bb461247c68b34115e596fb2da: jid=964910582733.1566 started=1 finished=0
# ASYNC POLL on 59794c67db354b7f87340624c04e4dd0: jid=578073256651.1453 started=1 finished=0
# ASYNC POLL on af385a34e484447bbad51afad3beb5c8: jid=546766599326.1450 started=1 finished=0
# ASYNC POLL on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444 started=1 finished=0
# ASYNC POLL on 7b30252402984d268d838fc9a8468fb7: jid=268053956713.1519 started=1 finished=0
# ASYNC POLL on 419951bb461247c68b34115e596fb2da: jid=964910582733.1566 started=1 finished=0
# ASYNC POLL on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444 started=1 finished=0
# ASYNC OK on 59794c67db354b7f87340624c04e4dd0: jid=578073256651.1453
# ASYNC OK on af385a34e484447bbad51afad3beb5c8: jid=546766599326.1450
# changed: [59794c67db354b7f87340624c04e4dd0]
# changed: [af385a34e484447bbad51afad3beb5c8]
# ASYNC POLL on 7b30252402984d268d838fc9a8468fb7: jid=268053956713.1519 started=1 finished=0
# ASYNC OK on 419951bb461247c68b34115e596fb2da: jid=964910582733.1566
# changed: [419951bb461247c68b34115e596fb2da]
# ASYNC OK on 4845d9798a284a6c9186c949c3cbb3d4: jid=83093572273.1444
# changed: [4845d9798a284a6c9186c949c3cbb3d4]
# ASYNC POLL on 1c674064c6324a90a13bf6b092afd80a: jid=788147514374.1931 started=1 finished=0
# ASYNC POLL on 055a1b8ed33e4070b12f8544aea86cd2: jid=227675094120.1514 started=1 finished=0
# ASYNC POLL on 7b30252402984d268d838fc9a8468fb7: jid=268053956713.1519 started=1 finished=0
# ASYNC POLL on 5b9555a28ceb47e0b64aa6eafe108c9a: jid=317439614837.1571 started=1 finished=0
# ASYNC POLL on 055a1b8ed33e4070b12f8544aea86cd2: jid=227675094120.1514 started=1 finished=0
# ASYNC POLL on 1c674064c6324a90a13bf6b092afd80a: jid=788147514374.1931 started=1 finished=0
# ASYNC POLL on dc8897c9bd31486dab80009367ef3385: jid=717436480313.1569 started=1 finished=0
# ASYNC POLL on 7b30252402984d268d838fc9a8468fb7: jid=268053956713.1519 started=1 finished=0
# ASYNC POLL on 5b9555a28ceb47e0b64aa6eafe108c9a: jid=317439614837.1571 started=1 finished=0
# ASYNC POLL on 055a1b8ed33e4070b12f8544aea86cd2: jid=227675094120.1514 started=1 finished=0
# ASYNC POLL on dc8897c9bd31486dab80009367ef3385: jid=717436480313.1569 started=1 finished=0
# ASYNC OK on 1c674064c6324a90a13bf6b092afd80a: jid=788147514374.1931
# changed: [1c674064c6324a90a13bf6b092afd80a]
# ASYNC OK on 7b30252402984d268d838fc9a8468fb7: jid=268053956713.1519
# changed: [7b30252402984d268d838fc9a8468fb7]
# ASYNC OK on 5b9555a28ceb47e0b64aa6eafe108c9a: jid=317439614837.1571
# changed: [5b9555a28ceb47e0b64aa6eafe108c9a]
# ASYNC POLL on 055a1b8ed33e4070b12f8544aea86cd2: jid=227675094120.1514 started=1 finished=0
# ASYNC OK on dc8897c9bd31486dab80009367ef3385: jid=717436480313.1569
# changed: [dc8897c9bd31486dab80009367ef3385]
# ASYNC POLL on 98eaa8f47b444cf3afc295102886c2ac: jid=421352611458.1572 started=1 finished=0
# ASYNC POLL on 9b52a6a911cd401bb4c0e7985a12089a: jid=804970627623.1695 started=1 finished=0
# ASYNC POLL on b73ea280daca4f91a50b13844ba26b3c: jid=493647216383.1694 started=1 finished=0
# ASYNC OK on 055a1b8ed33e4070b12f8544aea86cd2: jid=227675094120.1514
# changed: [055a1b8ed33e4070b12f8544aea86cd2]
# ASYNC POLL on 98eaa8f47b444cf3afc295102886c2ac: jid=421352611458.1572 started=1 finished=0
# ASYNC POLL on 17505645616247a79c8f70ffd08778c1: jid=919471152747.1609 started=1 finished=0
# ASYNC OK on 9b52a6a911cd401bb4c0e7985a12089a: jid=804970627623.1695
# changed: [9b52a6a911cd401bb4c0e7985a12089a]
# ASYNC OK on b73ea280daca4f91a50b13844ba26b3c: jid=493647216383.1694
# changed: [b73ea280daca4f91a50b13844ba26b3c]
# ASYNC POLL on 17505645616247a79c8f70ffd08778c1: jid=919471152747.1609 started=1 finished=0
# ASYNC OK on 98eaa8f47b444cf3afc295102886c2ac: jid=421352611458.1572
# changed: [98eaa8f47b444cf3afc295102886c2ac]
# ASYNC OK on 17505645616247a79c8f70ffd08778c1: jid=919471152747.1609
# changed: [17505645616247a79c8f70ffd08778c1]
#
# PLAY RECAP *********************************************************************
# 055a1b8ed33e4070b12f8544aea86cd2 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 17505645616247a79c8f70ffd08778c1 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 1c674064c6324a90a13bf6b092afd80a : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 419951bb461247c68b34115e596fb2da : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 4845d9798a284a6c9186c949c3cbb3d4 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 59794c67db354b7f87340624c04e4dd0 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 5b9555a28ceb47e0b64aa6eafe108c9a : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 7b30252402984d268d838fc9a8468fb7 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 98eaa8f47b444cf3afc295102886c2ac : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 9b52a6a911cd401bb4c0e7985a12089a : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# af385a34e484447bbad51afad3beb5c8 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# b73ea280daca4f91a50b13844ba26b3c : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# bd768c6a66f445e7a11351a667e42b8a : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# dc8897c9bd31486dab80009367ef3385 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# fcd71ec358ca49bcb6e43257a90b5b68 : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %%
result_dir = Path(f"{os.getcwd()}/results/")
extra_args = {
    "bench": "in.rhodo",
    "results_dir": str(result_dir)
}

res = role_manager.perform_action("lammps", "fetch", node_ids, extra_args=extra_args)
# Out:
# PLAY [Fetch results] ***********************************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [4845d9798a284a6c9186c949c3cbb3d4]
# ok: [bd768c6a66f445e7a11351a667e42b8a]
# ok: [af385a34e484447bbad51afad3beb5c8]
# ok: [fcd71ec358ca49bcb6e43257a90b5b68]
# ok: [59794c67db354b7f87340624c04e4dd0]
# ok: [7b30252402984d268d838fc9a8468fb7]
# ok: [419951bb461247c68b34115e596fb2da]
# ok: [5b9555a28ceb47e0b64aa6eafe108c9a]
# ok: [1c674064c6324a90a13bf6b092afd80a]
# ok: [055a1b8ed33e4070b12f8544aea86cd2]
# ok: [98eaa8f47b444cf3afc295102886c2ac]
# ok: [17505645616247a79c8f70ffd08778c1]
# ok: [9b52a6a911cd401bb4c0e7985a12089a]
# ok: [dc8897c9bd31486dab80009367ef3385]
# ok: [b73ea280daca4f91a50b13844ba26b3c]
#
# TASK [Find LAMMPS outputs files] ***********************************************
# ok: [4845d9798a284a6c9186c949c3cbb3d4]
# ok: [fcd71ec358ca49bcb6e43257a90b5b68]
# ok: [59794c67db354b7f87340624c04e4dd0]
# ok: [bd768c6a66f445e7a11351a667e42b8a]
# ok: [af385a34e484447bbad51afad3beb5c8]
# ok: [419951bb461247c68b34115e596fb2da]
# ok: [7b30252402984d268d838fc9a8468fb7]
# ok: [5b9555a28ceb47e0b64aa6eafe108c9a]
# ok: [1c674064c6324a90a13bf6b092afd80a]
# ok: [055a1b8ed33e4070b12f8544aea86cd2]
# ok: [dc8897c9bd31486dab80009367ef3385]
# ok: [98eaa8f47b444cf3afc295102886c2ac]
# ok: [9b52a6a911cd401bb4c0e7985a12089a]
# ok: [b73ea280daca4f91a50b13844ba26b3c]
# ok: [17505645616247a79c8f70ffd08778c1]
#
# TASK [Copy files] **************************************************************
# changed: [4845d9798a284a6c9186c949c3cbb3d4] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.2.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655477799.1728206, 'mtime': 1655477799.1728206, 'ctime': 1655477799.1728206, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [bd768c6a66f445e7a11351a667e42b8a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655477799.1412954, 'mtime': 1655477799.1412954, 'ctime': 1655477799.1412954, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [59794c67db354b7f87340624c04e4dd0] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.2.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 51713, 'nlink': 1, 'atime': 1655477799.3317776, 'mtime': 1655477799.3317776, 'ctime': 1655477799.3317776, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [af385a34e484447bbad51afad3beb5c8] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.2.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278848, 'dev': 51713, 'nlink': 1, 'atime': 1655477799.329353, 'mtime': 1655477799.329353, 'ctime': 1655477799.329353, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [fcd71ec358ca49bcb6e43257a90b5b68] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.4.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12302, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655477799.196758, 'mtime': 1655477925.3057427, 'ctime': 1655477925.3057427, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [4845d9798a284a6c9186c949c3cbb3d4] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.2.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12303, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655477799.1728206, 'mtime': 1655478005.7510784, 'ctime': 1655478005.7510784, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [fcd71ec358ca49bcb6e43257a90b5b68] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.4.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655477799.196758, 'mtime': 1655477799.196758, 'ctime': 1655477799.196758, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [bd768c6a66f445e7a11351a667e42b8a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12300, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655477799.1412954, 'mtime': 1655477866.4210112, 'ctime': 1655477866.4210112, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [59794c67db354b7f87340624c04e4dd0] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.2.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12303, 'inode': 278845, 'dev': 51713, 'nlink': 1, 'atime': 1655477799.3317776, 'mtime': 1655477982.2355413, 'ctime': 1655477982.2355413, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [af385a34e484447bbad51afad3beb5c8] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.2.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12303, 'inode': 278847, 'dev': 51713, 'nlink': 1, 'atime': 1655477799.3253531, 'mtime': 1655477975.6689243, 'ctime': 1655477975.6689243, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [419951bb461247c68b34115e596fb2da] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655477907.1593337, 'mtime': 1655477907.1593337, 'ctime': 1655477907.1593337, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [7b30252402984d268d838fc9a8468fb7] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.4.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12302, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655477939.4230487, 'mtime': 1655478069.5541058, 'ctime': 1655478069.5541058, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [5b9555a28ceb47e0b64aa6eafe108c9a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278848, 'dev': 51713, 'nlink': 1, 'atime': 1655478012.901646, 'mtime': 1655478012.901646, 'ctime': 1655478012.901646, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [1c674064c6324a90a13bf6b092afd80a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 51713, 'nlink': 1, 'atime': 1655478003.4024723, 'mtime': 1655478003.4024723, 'ctime': 1655478003.4024723, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [055a1b8ed33e4070b12f8544aea86cd2] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.4.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12302, 'inode': 278845, 'dev': 51713, 'nlink': 1, 'atime': 1655478003.6175144, 'mtime': 1655478161.9775357, 'ctime': 1655478161.9775357, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [419951bb461247c68b34115e596fb2da] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12301, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655477907.1553338, 'mtime': 1655477983.3846037, 'ctime': 1655477983.3846037, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [7b30252402984d268d838fc9a8468fb7] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.4.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655477939.4270487, 'mtime': 1655477939.4270487, 'ctime': 1655477939.4270487, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [5b9555a28ceb47e0b64aa6eafe108c9a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12302, 'inode': 278847, 'dev': 51713, 'nlink': 1, 'atime': 1655478012.901646, 'mtime': 1655478094.6727278, 'ctime': 1655478094.6727278, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [055a1b8ed33e4070b12f8544aea86cd2] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.4.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 51713, 'nlink': 1, 'atime': 1655478003.6175144, 'mtime': 1655478003.6175144, 'ctime': 1655478003.6175144, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [1c674064c6324a90a13bf6b092afd80a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12302, 'inode': 278845, 'dev': 51713, 'nlink': 1, 'atime': 1655478003.4024723, 'mtime': 1655478085.0256755, 'ctime': 1655478085.0256755, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [dc8897c9bd31486dab80009367ef3385] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655478036.2854316, 'mtime': 1655478036.2854316, 'ctime': 1655478036.2854316, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [98eaa8f47b444cf3afc295102886c2ac] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655478110.1745875, 'mtime': 1655478110.1745875, 'ctime': 1655478110.1745875, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [9b52a6a911cd401bb4c0e7985a12089a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.16.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655478110.8077197, 'mtime': 1655478110.8077197, 'ctime': 1655478110.8077197, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [b73ea280daca4f91a50b13844ba26b3c] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.16.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 66305, 'nlink': 1, 'atime': 1655478119.544188, 'mtime': 1655478119.544188, 'ctime': 1655478119.544188, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [17505645616247a79c8f70ffd08778c1] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stderr', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 0, 'inode': 278846, 'dev': 51713, 'nlink': 1, 'atime': 1655478143.2844682, 'mtime': 1655478143.2844682, 'ctime': 1655478143.2844682, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [dc8897c9bd31486dab80009367ef3385] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12301, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655478036.2854316, 'mtime': 1655478106.7093544, 'ctime': 1655478106.7093544, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [98eaa8f47b444cf3afc295102886c2ac] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12300, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655478110.1745875, 'mtime': 1655478180.5392447, 'ctime': 1655478180.5392447, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [9b52a6a911cd401bb4c0e7985a12089a] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.16.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12304, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655478110.8077197, 'mtime': 1655478145.140896, 'ctime': 1655478145.140896, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [b73ea280daca4f91a50b13844ba26b3c] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.16.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12304, 'inode': 278845, 'dev': 66305, 'nlink': 1, 'atime': 1655478119.540188, 'mtime': 1655478161.6562533, 'ctime': 1655478161.6562533, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
# changed: [17505645616247a79c8f70ffd08778c1] => (item={'path': '/home/ubuntu/mo833-lammps/in.rhodo.results.N.8.stdout', 'mode': '0644', 'isdir': False, 'ischr': False, 'isblk': False, 'isreg': True, 'isfifo': False, 'islnk': False, 'issock': False, 'uid': 1000, 'gid': 1000, 'size': 12302, 'inode': 278845, 'dev': 51713, 'nlink': 1, 'atime': 1655478143.2844682, 'mtime': 1655478228.4242148, 'ctime': 1655478228.4242148, 'gr_name': 'ubuntu', 'pw_name': 'ubuntu', 'wusr': True, 'rusr': True, 'xusr': False, 'wgrp': False, 'rgrp': True, 'xgrp': False, 'woth': False, 'roth': True, 'xoth': False, 'isuid': False, 'isgid': False})
#
# PLAY RECAP *********************************************************************
# 055a1b8ed33e4070b12f8544aea86cd2 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 17505645616247a79c8f70ffd08778c1 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 1c674064c6324a90a13bf6b092afd80a : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 419951bb461247c68b34115e596fb2da : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 4845d9798a284a6c9186c949c3cbb3d4 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 59794c67db354b7f87340624c04e4dd0 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 5b9555a28ceb47e0b64aa6eafe108c9a : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 7b30252402984d268d838fc9a8468fb7 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 98eaa8f47b444cf3afc295102886c2ac : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# 9b52a6a911cd401bb4c0e7985a12089a : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# af385a34e484447bbad51afad3beb5c8 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# b73ea280daca4f91a50b13844ba26b3c : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# bd768c6a66f445e7a11351a667e42b8a : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# dc8897c9bd31486dab80009367ef3385 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# fcd71ec358ca49bcb6e43257a90b5b68 : ok=3    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %%
nodes_file = result_dir / "nodes.yaml"
nodes = [
    asdict(node)
    for node in node_manager.get_nodes_by_id(node_ids)
]

with nodes_file.open("w") as f:
    yaml.dump(nodes, f, indent=4, sort_keys=True)

# %%
cluster_manager.stop_cluster(cluster.cluster_id)
# Out:
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
# [DEPRECATION WARNING]: amazon.aws.ec2 has been deprecated. The ec2 module is
# based upon a deprecated version of the AWS SDKs and is deprecated in favor of
# the ec2_instance module. Please update your tasks. This feature will be removed
#  from amazon.aws in version 4.0.0. Deprecation warnings can be disabled by
# setting deprecation_warnings=False in ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Stopping nodes BarbaraMorgan, BoydWalton, BrittanyLohmann, DerekBenningfield, GeorginaLy, GladysLee, KennethLeslie, MaryLewis, MattieRousse, RyanOliver, SarahDemello, ShaneMadore, SharonWarner, SusanSchwalb, WilliamLouder] ***
# deprecation_warnings=False in ansible.cfg.
# changed: [localhost]
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=1    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# ['59794c67db354b7f87340624c04e4dd0',
#  'af385a34e484447bbad51afad3beb5c8',
#  '4845d9798a284a6c9186c949c3cbb3d4',
#  'bd768c6a66f445e7a11351a667e42b8a',
#  'fcd71ec358ca49bcb6e43257a90b5b68',
#  '419951bb461247c68b34115e596fb2da',
#  '7b30252402984d268d838fc9a8468fb7',
#  '055a1b8ed33e4070b12f8544aea86cd2',
#  '1c674064c6324a90a13bf6b092afd80a',
#  '5b9555a28ceb47e0b64aa6eafe108c9a',
#  'dc8897c9bd31486dab80009367ef3385',
#  '98eaa8f47b444cf3afc295102886c2ac',
#  '9b52a6a911cd401bb4c0e7985a12089a',
#  'b73ea280daca4f91a50b13844ba26b3c',
#  '17505645616247a79c8f70ffd08778c1']
